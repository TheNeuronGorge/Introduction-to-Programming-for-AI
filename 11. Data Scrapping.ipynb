# %% [markdown]
# # The Neuron Gorge
# # https://sites.google.com/view/theneurongorge
#
#
# # What is Web Scraping

# %% [markdown]
# Web scraping is a technique used in the field of data extraction and web automation. It involves programmatically fetching and extracting information from websites. Web scraping enables the automated retrieval of data, such as text, images, tables, or other structured content, from web pages, and it can be useful for a wide range of applications, including data analysis, research, content aggregation, price monitoring, and more.

# %% [markdown]
# ### Selenium

# %% [markdown]
# One popular tool for web scraping is Selenium, which is a web automation framework. Selenium allows you to interact with websites in a way that simulates human browsing behavior. It can be used to automate tasks like filling out forms, clicking buttons, and navigating through web pages, making it a powerful tool for web scraping.
#
# Selenium can be integrated with multiple programming languages like Python, Java, C#, Ruby, and JavaScript.
#
# However, it's important to note that web scraping, including the use of Selenium, should be conducted ethically and in compliance with the website's terms of service and legal regulations.

# %% [markdown]
# ### Selenium Python Tutorial

# %% [markdown]
# Install The Necessary Libraries

# %%
# !pip install selenium
# !pip install webdriver-manager
# Out:
# ...
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# ...

# %% [markdown]
# Ensure that your web browser is up to date to its latest version.

# %%
#Importing the necessary libraries

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# ### Google Chrome

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# %% [markdown]
# ### Firefox

# %%
from selenium import webdriver
from selenium.webdriver.firefox.service import Service as FirefoxService
from webdriver_manager.firefox import GeckoDriverManager

driver = webdriver.Firefox(service=FirefoxService(GeckoDriverManager().install()))

# %% [markdown]
# Please provide the URL of the webpage you'd like to Automate/Scrape.

# %%
url = 'https://www.daraz.pk/'

# %% [markdown]
# Give the URL to the Driver

# %%
driver.get(url)

# %% [markdown]
# Getting the Daraz Search Bar

# %%
search_bar = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[1]/div/div/div[2]/div/div[2]/form/div/div[1]/input[1]')
search_bar.send_keys('Samsung' + Keys.RETURN)

# %% [markdown]
# Alternative methods for finding elements besides XPath.
#
# i) By.ID<br>
# ii) By.NAME<br>
# iii) By.LINK_TEXT<br>
# iv) By.TAG_NAME<br>
# v) By.CLASS_NAME<br>
# vi) By.XPATH

# %% [markdown]
# Example of Finding Elements by Tag Name

# %%
driver.find_element(By.TAG_NAME, 'div').text
# Out:
# 'Become a Seller Daraz Affiliate Program Help & Support\nSEARCH\nLogin\n|\nCategories'

# %% [markdown]
# Finding Multiple Elements with same HTML Tag

# %%
driver.find_elements(By.TAG_NAME, 'div')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="242b36a221a05b5a57b6aadb34caf64c", element="BC44CA3EF6B5A4374F9CE334B9A6FF83_element_3670")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="242b36a221a05b5a57b6aadb34caf64c", element="BC44CA3EF6B5A4374F9CE334B9A6FF83_element_3671")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="242b36a221a05b5a57b6aadb34caf64c", element="BC44CA3EF6B5A4374F9CE334B9A6FF83_element_3672")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="242b36a221a05b5a57b6aadb34caf64c", element="BC44CA3EF6B5A4374F9CE334B9A6FF83_element_3673")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="242b36a221a05b5a57b6aadb34caf64c", element="BC44CA3EF6B5A4374F9CE334B9A6FF83_element_3674")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="242b36a221a05b5a57b6aadb34caf64c", element="BC44CA3EF6B5A4374F9CE334B9A6FF83_element_3675")>,
# ...

# %% [markdown]
# Extracting Text From Specific Element

# %%
driver.find_element(By.XPATH, '/html/body/div[3]/div/div[4]/div/div/div[1]/div[2]/div[1]/div/div/div[2]/div[2]/a').text
# Out:
# 'Samsung A14 6/128'

# %% [markdown]
# ### Relative Path

# %%
ad_grid = driver.find_element(By.XPATH, '/html/body/div[3]/div/div[4]/div/div/div[1]/div[2]')
ad_cards = ad_grid.find_elements(By.CLASS_NAME, 'gridItem--Yd0sa')

for i in ad_cards:
    print(i.text)
# Out:
# Samsung A14 6/128
# Rs. 53,999
# Rs. 64,999-17%
# (75)
# Pakistan
# Samsung Galaxy Tab E - 1.5GB RAM - Android 7 - FREE TABLET COVER - Wi-Fi Only
# Rs. 13,999
# Rs. 19,999-30%
# (29)
# Free Shipping
# Samsung A24 8GB+128GB
# Rs. 72,999
# Rs. 79,999-9%
# (51)
# Pakistan
# Samsung A14 4/128
# Rs. 50,899
# Rs. 62,999-19%
# (138)
# Pakistan
# Daraz Like New Tablets - Samsung Galaxy Tab A 8.0" 2GB 32GB, Black Wi-Fi Supported - FREE TABLET COVER
# Rs. 15,899
# Rs. 24,999-36%
# (34)
# Free Shipping
# Samsung Galaxy Tab E - 1.5GB RAM - 16GB ROM - Android 7 - FREE TABLET COVER
# Rs. 13,659
# Rs. 24,999-45%
# (24)
# Free Shipping
# Daraz Like New Tablets - Samsung Galaxy Tab A 8.0" 2GB 32GB, Black Wi-Fi Supported - Tablets - FREE TABLET COVER - PUBG SUPPORTE - MODEL - T387
# Rs. 15,599
# Rs. 24,999-38%
# (11)
# Free Shipping
# Daraz Like New Tablets - Samsung Galaxy Tab A Model: Sm-T387 8.0 inch Display 2GB RAM 32GB Memory- Original Protector Installed
# Rs. 15,499
# Rs. 22,999-33%
# (2)
# ...

# %% [markdown]
# Clicking on an Element on Web Page

# %%
ad_cards[0].click()

# %% [markdown]
# ### Common Exceptions

# %% [markdown]
# #### NoSuchElementException
# When driver is unable to find the element specified in the find_element() function.<br>
# -Check if you have specified the right path<br>
# -Chek if driver is on the same page as the specified path
#
# #### StaleElementReferenceException
# The Element you're trying to access is being blocked by some other element.<br>
# -Try to access the element in loop

# %% [markdown]
# ### Code for Scraping Reviews of a Product on Daraz

# %%
url = 'https://www.daraz.pk/products/daraz-like-new-tablets-samsung-galaxy-tab-a-80-2gb-32gb-black-wi-fi-supported-free-tablet-cover-i411369268-s1965198370.html?spm=a2a0e.searchlist.list.1.3c784ce9COfUfG&search=1'

# %% [markdown]
# -The time.sleep() function can be used to introduce a brief pause, allowing the webpage to load successfully.<br>
# -For automated scrolling within a webpage, you can utilize driver.execute_script("window.scrollTo(0, 500);").

# %%
import time
import pandas as pd

driver.get(url)

temp = dict()
temp['Name'] = []
temp['Review text'] = []

driver.execute_script("window.scrollTo(0, 500);")
time.sleep(1)
driver.execute_script("window.scrollTo(500, 800);")
time.sleep(1)
driver.execute_script("window.scrollTo(800, 1000);")
time.sleep(2)
driver.execute_script("window.scrollTo(1000, 1300);")
time.sleep(2)
driver.execute_script("window.scrollTo(1300, 1600);")
time.sleep(1)

for page in range(0,3):
    try:
        reviews_container = driver.find_element(By.XPATH, '//*[@id="module_product_review"]/div/div/div[3]/div[1]')
    except NoSuchElementException:
        print('No Reviews')
        break
    reviews = reviews_container.find_elements(By.CLASS_NAME,'item')

    for i in range(len(reviews)):
        if reviews[i].find_element(By.CSS_SELECTOR, f"#module_product_review > div > div > div:nth-child(3) > div.mod-reviews > div:nth-child({i+1}) > div.item-content > div.content").text != '':
            temp['Name'].append(reviews[i].find_element(By.CLASS_NAME,'middle').find_element(By.TAG_NAME,'span').text[3:])
            temp['Review text'].append(reviews[i].find_element(By.CSS_SELECTOR, f"#module_product_review > div > div > div:nth-child(3) > div.mod-reviews > div:nth-child({i+1}) > div.item-content > div.content").text)

    try:
        if(page != 2):
            nxt_button = driver.find_element(By.XPATH, '//*[@id="module_product_review"]/div/div/div[3]/div[2]/div/button[2]')
            driver.execute_script("arguments[0].click();", nxt_button)
            time.sleep(5)
    except NoSuchElementException:
        print('No More Pages')
        break

reviews = pd.DataFrame(temp)

reviews
# Out:
#             Name                                        Review text
# 0          Salah  Ordered two, received on time and well packed....
# 1          Dr U.  Excellent Quality.Just like new. Needs eagle e...
# 2          R***.  Cover was missing and charger was not original...
# 3      Paryal G.  Tablet bahut Achcha Hai charger original nahin...
# 4   Waqasraza R.                                      thanks saller
# 5          3***2  Marvelous quality,All tabs are 10/10 , charger...
# 6          3***3                                   very nice tablet
# 7    Muhammed M.  Order received on time very good packing over ...
# 8       sajid H.  I got a faulty tablet but then they changed an...
# 9         Hafeez  mind blowing thing! condition wise 10/10 and b...
# 10     Meshal F.  I'm very pleased with this product. The six mo...
# 11        Ali S.                          I have received my parcel
# 12      Sarah H.  Tablet’s quality is good, just like new. Howev...
# ...

# %%
url = 'https://en.wikipedia.org/wiki/List_of_universities_in_Pakistan'

driver.get(url)

# %%
tables = driver.find_elements(By.XPATH, "//table[@class='wikitable sortable jquery-tablesorter']")

# %%
links = {}

table = tables[0]

body = table.find_element(By.TAG_NAME, 'tbody')
rows = body.find_elements(By.TAG_NAME, 'tr')
for row in rows:
    uni_name = row.find_element(By.TAG_NAME, 'td')
    try:
        uni_link = uni_name.find_element(By.TAG_NAME, 'a')
        links[uni_name.text]=uni_link.get_attribute('href')
    except NoSuchElementException:
        pass

    driver.execute_script(f"window.open('{uni_link.get_attribute('href')}','secondtab');")
    driver.switch_to.window(driver.window_handles[1])

    driver.execute_script("window.scrollTo(0, 500);")
    time.sleep(2)
    driver.execute_script("window.scrollTo(500, 800);")
    time.sleep(2)
    driver.execute_script("window.scrollTo(800, 1000);")

    driver.close()
    driver.switch_to.window(driver.window_handles[0])

# %%
links
# Out:
# {'1 Riphah International University': 'https://en.wikipedia.org/wiki/Riphah_International_University',
#  '2 Capital University of Science & Technology': 'https://en.wikipedia.org/wiki/Capital_University_of_Science_%26_Technology',
#  '3 Quaid-i-Azam University': 'https://en.wikipedia.org/wiki/Quaid-i-Azam_University',
#  '4 Pakistan Institute of Engineering and Applied Sciences': 'https://en.wikipedia.org/wiki/Pakistan_Institute_of_Engineering_and_Applied_Sciences',
#  '5 National Defence University, Pakistan': 'https://en.wikipedia.org/wiki/National_Defence_University,_Pakistan',
#  '6 Allama Iqbal Open University': 'https://en.wikipedia.org/wiki/Allama_Iqbal_Open_University',
#  '7 International Islamic University, Islamabad': 'https://en.wikipedia.org/wiki/International_Islamic_University,_Islamabad',
#  '8 National University of Sciences and Technology, Pakistan': 'https://en.wikipedia.org/wiki/National_University_of_Sciences_and_Technology,_Pakistan',
# ...

# %%
url = 'http://isb.nu.edu.pk/Faculty/allfaculty'
driver.get(url)

# %%
from IPython.display import display, HTML
import pandas as pd

facultyCS = driver.find_element(By.ID, 'facultyCS')

profiles = facultyCS.find_elements(By.XPATH, './div')

df=[]
for profile in profiles:
    data=profile.text.splitlines()

    image_src = profile.find_element(By.TAG_NAME, 'img').get_attribute('src')

    data.append(image_src)

    df.append(data)

column_names = ['Name', 'Designation', 'Email', 'Imagesrc']

df = pd.DataFrame(df, columns=column_names)

# Function to display image in DataFrame
def display_image(image_src):
    return f'<img src="{image_src}" width="100" />'

# Apply the display_image function to the 'ImageSrc' column
df['Image'] = df['Imagesrc'].apply(display_image)
df = df.drop('Imagesrc', axis=1)

# Close the browser
driver.quit()

# Display the DataFrame with images
display(HTML(df.to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Designation</th>
#       <th>Email</th>
#       <th>Image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Waseem Shahzad</td>
#       <td>Director & Professor</td>
#       <td>waseem.shahzad@nu.edu.pk</td>
#       <td><img src="http://isb.nu.edu.pk/Images/Profile/CS/4553.jpg" width="100" /></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Kashif Munir</td>
#       <td>Head, School of Computing & Professor</td>
#       <td>kashif.munir@nu.edu.pk</td>
#       <td><img src="http://isb.nu.edu.pk/Images/Profile/CS/36292021-01-21_23.28.18.jpg" width="100" /></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Hammad Majeed</td>
#       <td>HoD (Computer Science) & Professor</td>
#       <td>hammad.majeed@nu.edu.pk</td>
# ...

# %% [markdown]
# # Beautiful Soup / Requests

# %%
# !pip install beautifulsoup4
# !pip install requests
# Out:
# ...
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\muhammad_sohail\anaconda3\lib\site-packages)
# ...

# %%
from bs4 import BeautifulSoup
import requests
url = "https://en.wikipedia.org/wiki/Muhammad_Ali_Jinnah"
req = requests.get(url)
soup = BeautifulSoup(req.text, "html.parser")
print(soup.title)
# Out:
# <title>Muhammad Ali Jinnah - Wikipedia</title>

# %%
soup.body
# Out:
# <body class="skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Muhammad_Ali_Jinnah rootpage-Muhammad_Ali_Jinnah skin-vector-2022 action-view"><a class="mw-jump-link" href="#bodyContent">Jump to content</a>
# <div class="vector-header-container">
# <header class="vector-header mw-header">
# <div class="vector-header-start">
# <nav aria-label="Site" class="vector-main-menu-landmark" role="navigation">
# <div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
# <input aria-haspopup="true" aria-label="Main menu" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
# ...

# %%
print(soup.text)
# Out:
# Muhammad Ali Jinnah - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
# Languages
#
# Language links are at the top of the page across from the title.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
# Create accountLog in
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
#  Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1Early years
#
#
#
# Toggle Early years subsection
#
#
#
#
#
# 1.1Family and childhood
#
#
#
#
#
#
#
# 1.2Education in England
#
#
#
#
#
#
# ...

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=Muhammad+Ali+Jinnah
# /w/index.php?title=Special:UserLogin&returnto=Muhammad+Ali+Jinnah
# /w/index.php?title=Special:CreateAccount&returnto=Muhammad+Ali+Jinnah
# /w/index.php?title=Special:UserLogin&returnto=Muhammad+Ali+Jinnah
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_years
# #Family_and_childhood
# #Education_in_England
# #Legal_and_early_political_career
# #Barrister
# ...

# %% [markdown]
# # Lab Tasks
# 1. Use selinium and goto https://www.amazon.com/ search for swing.
# 2. Get some description, price and pic
# 3. Show all in a dataframe.

# %% [markdown]
# b. In above task, click on a swing and get it's reviews, you may need to scroll for all reviews

# %% [markdown]
# 1. Use selinium and goto https://www.phdportal.com/search/phd/germany
# 2. Get Degree name, Instituion name, tution fee (free, unknow, some number), and city name.
# 3. Show all data in a dataframe.
